# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame

#Kyle Dyer


#Load code in
data = pd.read_csv('titanic_data.csv')

data.head()



#data['Siblings/Spouses Aboard'].value_counts()

#plt.hist(data['Fare'])
#plt.show

#MOST NOTICEABLE PATTERN BELOW

data.plot(kind="scatter",x="Age",y = "Fare", c= "Survived",colormap='plasma')
plt.show()

#data.plot(kind="scatter",x="Siblings/Spouses Aboard",y = "Fare", c= "Survived",colormap='plasma')
#plt.show()

#data.plot(kind="scatter",x="Parents/Children Aboard",y = "Fare", c= "Survived",colormap='plasma')
#plt.show()

# %%
#Usable Features

#Age and Fare will be the most usable feataures as they are more continuous than the rest of the features. That being said,
#siblings/spouses and parents/children aboard might show some correlations as well as Pclass but it will be harder to find
#patterns in the data.

#Target

#Our target is if a passenger survived or not.

#Patterns

#There seems to exist a relationship between the age, fare paid, and if someone survived or not. My hypothesis is that high
#fare and younger passengers were most likely to survive than older and low fare passengers. That being said, age can be less
#of a factor if the passenger is very high fared.
